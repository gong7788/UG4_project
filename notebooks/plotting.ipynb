# %%
from experiment import add_experiment
from experiment_tracking import read_experiments, get_results_file, get_baseline, load_experiments
from evaluation import test_colour_model, colour_probs, colour_dict, name_to_rgb
from util import add_config_option, create_experiment
import pandas as pd
# %matplotlib inline
labels = ['Language', 'No Language', 'Naive']

# %%
df = read_experiments()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#                                       config_name  \
# index
# 0                                            None
# 1                                   simple_neural
# 2                              neural_onerule5000
# 3                              neural_onerule5000
# 4                              neural_onerule5000
# 5                              neural_onerule5000
# 6                                        tworules
# 7                              tworules_no_update
# 8                                        tworules
# 9                              tworules_no_update
# 10                                       tworules
# 11                                        onerule
# 12                        onerule_update_negative
# 13                                       tworules
# 14                       tworules_update_negative
# 15                        tworules_perfect_colour
# 16                    tworules_perfect_colour_vis
# 17                        tworules_perfect_colour
# 18                                       tworules
# 19                       tworules_update_negative
# 20                                       tworules
# 21                                       tworules
# 22                       tworules_update_negative
# 23                           tworules_update_once
# 24                           tworules_update_once
# 25             tworules_update_once_with_negative
# 26                                       tworules
# 27                                       tworules
# 28                                       tworules
# 29                                       tworules
# 30                                       tworules
# 31                           tworules_update_once
# 32                                       tworules
# 33                                       tworules
# 34                                       tworules
# 35                                       tworules
# 36                       tworules_update_negative
# 37                                       tworules
# 38                                       tworules
# 39                       tworules_update_negative
# 40                           tworules_update_once
# 41             tworules_update_once_with_negative
# 42                                     simple_kde
# 43                                     simple_kde
# 44                                     simple_kde
# 45                                     simple_kde
# 46                                     simple_kde
# 47                                     simple_kde
# 48                                     simple_kde
# 49                                     simple_kde
# 50                                     simple_kde
# 51                                     simple_kde
# 52                                     simple_kde
# 53                                     simple_kde
# 54                                  simple_random
# 55                                        DEFAULT
# 56                         simple_update_negative
# 57                         simple_update_negative
# 58                         simple_update_negative
# 59                     simple_kde_update_negative
# 60                     simple_kde_update_negative
# 61                                    onerule_kde
# 62                    onerule_kde_update_negative
# 63                                   tworules_kde
# 64                   tworules_kde_update_negative
# 65                                     maroon_kde
# 66                                     maroon_kde
# 67                     maroon_kde_update_negative
# 68                                  bijection_kde
# 69                  bijection_kde_update_negative
# 70                                tworules_random
# 71                            onerule_update_once
# 72                            onerule_update_once
# 73              onerule_update_once_with_negative
# 74                          bijection_update_once
# 75                          bijection_update_once
# 76                          bijection_update_once
# 77            bijection_update_once_with_negative
# 78                             maroon_update_once
# 79               maroon_update_once_with_negative
# 80                                  maroon_random
# 81                               bijection_random
# 82                                    onerule_kde
# 83                                    onerule_kde
# 84                                    onerule_kde
# 85                                    onerule_kde
# 86                                    onerule_kde
# 87                                    onerule_kde
# 88                                    onerule_kde
# 89                                    onerule_kde
# 90                                    onerule_kde
# 91                                    onerule_kde
# 92                                   tworules_kde
# 93                   tworules_kde_update_negative
# 94                                     maroon_kde
# 95                     maroon_kde_update_negative
# 96                                  bijection_kde
# 97                  bijection_kde_update_negative
# 98                            onerule_update_once
# 99                                    onerule_kde
# 100                                  tworules_kde
# 101                  tworules_kde_update_negative
# 102                                    maroon_kde
# 103                    maroon_kde_update_negative
# 104                                 bijection_kde
# 105                 bijection_kde_update_negative
# 106             onerule_update_once_with_negative
# 107                                   onerule_kde
# 108                                  tworules_kde
# 109                                  tworules_kde
# 110                                  tworules_kde
# 111                                  tworules_kde
# 112                                  tworules_kde
# 113                                  tworules_kde
# 114                  tworules_kde_update_negative
# 115                                    maroon_kde
# 116                    maroon_kde_update_negative
# 117                                 bijection_kde
# 118                 bijection_kde_update_negative
# 119                           onerule_update_once
# 120             onerule_update_once_with_negative
# 121                         bijection_update_once
# 122           bijection_update_once_with_negative
# 123                            maroon_update_once
# 124              maroon_update_once_with_negative
# 125            tworules_update_once_with_negative
# 126                          tworules_update_once
# 127                                  tworules_kde
# 128                                    maroon_kde
# 129                                 bijection_kde
# 130                                   onerule_kde
# 131             onerule_update_once_with_negative
# 132           bijection_update_once_with_negative
# 133              maroon_update_once_with_negative
# 134            tworules_update_once_with_negative
# 135                                  tworules_kde
# 136                                  tworules_kde
# 137                                  tworules_kde
# 138                            onerule_kde_nocorr
# 139                            onerule_kde_nocorr
# 140                           tworules_kde_nocorr
# 141                             simple_nolanguage
# 142                             simple_nolanguage
# 143                             simple_nolanguage
# 144                             simple_nolanguage
# 145                             simple_nolanguage
# 146                             simple_nolanguage
# 147                             simple_nolanguage
# 148                             simple_nolanguage
# 149                             simple_nolanguage
# 150                             simple_nolanguage
# 151                            onerule_nolanguage
# 152                           tworules_nolanguage
# 153                             simple_nolanguage
# 154                             simple_nolanguage
# 155                             simple_nolanguage
# 156                             simple_nolanguage
# 157                             simple_nolanguage
# 158                             simple_nolanguage
# 159                             simple_nolanguage
# 160                             simple_nolanguage
# 161                            onerule_nolanguage
# 162                           tworules_nolanguage
# 163                                   onerule_kde
# 164                                   onerule_kde
# 165                                   onerule_kde
# 166                                  tworules_kde
# 167                                    maroon_kde
# 168                                 bijection_kde
# 169                                    simple_kde
# 170              simple_update_once_with_negative
# 171       simplecolours_update_once_with_negative
# 172       simplecolours_update_once_with_negative
# 173              simple_update_once_with_negative
# 174             onerule_update_once_with_negative
# 175              simple_update_once_with_negative
# 176             onerule_update_once_with_negative
# 177              simple_update_once_with_negative
# 178             onerule_update_once_with_negative
# 179            tworules_update_once_with_negative
# 180              maroon_update_once_with_negative
# 181           bijection_update_once_with_negative
# 182                             simple_nolanguage
# 183                             simple_nolanguage
# 184                             simple_nolanguage
# 185                             simple_nolanguage
# 186                            onerule_nolanguage
# 187                           tworules_nolanguage
# 188                           tworules_nolanguage
# 189                           tworules_nolanguage
# 190                           tworules_nolanguage
# 191                          bijection_nolanguage
# 192                             maroon_nolanguage
# 193                                   onerule_kde
# 194                                   onerule_kde
# 195                                  tworules_kde
# 196                                    maroon_kde
# 197                                 bijection_kde
# 198                                    simple_kde
# 199              simple_update_once_with_negative
# 200             onerule_update_once_with_negative
# 201            tworules_update_once_with_negative
# 202              maroon_update_once_with_negative
# 203           bijection_update_once_with_negative
# 204                                    simple_kde
# 205                                   onerule_kde
# 206                                  tworules_kde
# 207                                    maroon_kde
# 208                                 bijection_kde
# 209                    simple_kde_update_negative
# 210                   onerule_kde_update_negative
# 211                  tworules_kde_update_negative
# 212                    maroon_kde_update_negative
# 213                 bijection_kde_update_negative
# 214                    simple_kde_update_negative
# 215                    simple_kde_update_negative
# 216                   onerule_kde_update_negative
# 217                  tworules_kde_update_negative
# 218                    maroon_kde_update_negative
# 219                 bijection_kde_update_negative
# 220              simple_update_once_with_negative
# 221             onerule_update_once_with_negative
# 222            tworules_update_once_with_negative
# 223              maroon_update_once_with_negative
# 224           bijection_update_once_with_negative
# 225                                   onerule_kde
# 226                                  tworules_kde
# 227                                    maroon_kde
# 228                                 bijection_kde
# 229                                    simple_kde
# 230                                   onerule_kde
# 231                                  tworules_kde
# 232                                    maroon_kde
# 233                                 bijection_kde
# 234                                    simple_kde
# 235                                 simple_random
# 236                                onerule_random
# 237                               tworules_random
# 238                                 maroon_random
# 239                              bijection_random
# 240                          triplicatered200_kde
# 241                             simple_nolanguage
# 242                          triplicatered200_kde
# 243    triplicatered200_update_once_with_negative
# 244                       triplicatered200_random
# 245               triplicatered200_perfect_colour
# 246               triplicatered200_perfect_colour
# 247                              duplicatered_kde
# 248                              duplicatered_kde
# 249        duplicatered_update_once_with_negative
# 250                           duplicatered_random
# 251                   duplicatered_perfect_colour
# 252                         simple_perfect_colour
# 253                        onerule_perfect_colour
# 254                       tworules_perfect_colour
# 255                         maroon_perfect_colour
# 256                      bijection_perfect_colour
# 257                             simple_nolanguage
# 258                            onerule_nolanguage
# 259                           tworules_nolanguage
# 260                          bijection_nolanguage
# 261                             maroon_nolanguage
# 262                       duplicatered_nolanguage
# 263                       duplicatered_nolanguage
# 264                       duplicatered_nolanguage
# 265                      triplicatered_nolanguage
# 266                             triplicatered_kde
# 267                             triplicatered_kde
# 268                             triplicatered_kde
# 269       triplicatered_update_once_with_negative
# 270                          triplicatered_random
# 271                  triplicatered_perfect_colour
# 272                       triplicatered_no_colour
# 273                     triplicatered_no_language
# 274                      triplicatered_nolanguage
# 275                               tworules200_kde
# 276                             simple_nolanguage
# 277                               tworules200_kde
# 278                               tworules200_kde
# 279                               tworules200_kde
# 280                               tworules200_kde
# 281                               tworules200_kde
# 282         tworules200_update_once_with_negative
# 283                            tworules200_random
# 284                         tworules200_no_colour
# 285                      triplicatered_nolanguage
# 286                      triplicatered_nolanguage
# 287                      triplicatered_nolanguage
# 288                         tworules200_no_colour
# 289                        tworules200_nolanguage
# 290                      triplicatered_nolanguage
# 291                        tworules200_nolanguage
# 292                          tworules2_nolanguage
# 293                                 tworules2_kde
# 294                              tworules2_random
# 295                                 tworules2_kde
# 296                                 tworules2_kde
# 297                                 tworules2_kde
# 298                                 tworules2_kde
# 299                                 tworules2_kde
# 300                         threerules_nolanguage
# 301                                threerules_kde
# 302                             threerules_random
# 303                                threerules_kde
# 304                                threerules_kde
# 305                                threerules_kde
# 306                                threerules_kde
# 307                                threerules_kde
# 308                                threerules_kde
# 309                                threerules_kde
# 310                                 tworules2_kde
#
#                                          experiment_file  \
# index
# 0                                                   None
# 1      results/simplecolours/agents.NeuralCorrectingA...
# 2      results/onerule5000/agents.NeuralCorrectingAge...
# 3      results/onerule5000/agents.NeuralCorrectingAge...
# 4      results/onerule5000/agents.NeuralCorrectingAge...
# 5      results/onerule5000/agents.NeuralCorrectingAge...
# 6      results/tworules/agents.CorrectingAgent/0.7/ex...
# 7      results/tworules/agents.CorrectingAgent/0.7/ex...
# 8      results/tworules/agents.CorrectingAgent/0.7/ex...
# 9      results/tworules/agents.CorrectingAgent/0.7/ex...
# 10     results/tworules/agents.CorrectingAgent/0.7/ex...
# 11     results/onerule/agents.CorrectingAgent/0.7/exp...
# 12     results/onerule/agents.CorrectingAgent/0.7/exp...
# 13     results/tworules/agents.CorrectingAgent/0.7/ex...
# 14                                                  None
# 15     results/tworules/agents.PerfectColoursAgent/0....
# 16     results/tworules/agents.PerfectColoursAgent/0....
# 17                                                  None
# 18     results/tworules/agents.CorrectingAgent/0.7/ex...
# 19                                                  None
# 20                                                  None
# 21     results/tworules/agents.CorrectingAgent/0.7/ex...
# 22     results/tworules/agents.CorrectingAgent/0.7/ex...
# 23                                                  None
# 24     results/tworules/agents.CorrectingAgent/0.7/ex...
# 25     results/tworules/agents.CorrectingAgent/0.7/ex...
# 26                                                  None
# 27                                                  None
# 28                                                  None
# 29                                                  None
# 30                                                  None
# 31                                                  None
# 32                                                  None
# 33                                                  None
# 34                                                  None
# 35     results/tworules/agents.CorrectingAgent/0.7/ex...
# 36                                                  None
# 37                                                  None
# 38     results/tworules/agents.CorrectingAgent/0.7/ex...
# 39     results/tworules/agents.CorrectingAgent/0.7/ex...
# 40     results/tworules/agents.CorrectingAgent/0.7/ex...
# 41     results/tworules/agents.CorrectingAgent/0.7/ex...
# 42                                                  None
# 43                                                  None
# 44                                                  None
# 45                                                  None
# 46                                                  None
# 47                                                  None
# 48                                                  None
# 49                                                  None
# 50                                                  None
# 51                                                  None
# 52                                                  None
# 53     results/simplecolours/agents.CorrectingAgent/0...
# 54     results/simplecolours/agents.RandomAgent/0.7/e...
# 55     results/simplecolours/agents.CorrectingAgent/0...
# 56                                                  None
# 57                                                  None
# 58     results/simplecolours/agents.CorrectingAgent/0...
# 59                                                  None
# 60     results/simplecolours/agents.CorrectingAgent/0...
# 61     results/onerule/agents.CorrectingAgent/0.7/exp...
# 62     results/onerule/agents.CorrectingAgent/0.7/exp...
# 63     results/tworules/agents.CorrectingAgent/0.7/ex...
# 64     results/tworules/agents.CorrectingAgent/0.7/ex...
# 65                                                  None
# 66     results/maroon/agents.CorrectingAgent/0.7/expe...
# 67     results/maroon/agents.CorrectingAgent/0.7/expe...
# 68     results/bijection/agents.CorrectingAgent/0.7/e...
# 69     results/bijection/agents.CorrectingAgent/0.7/e...
# 70     results/tworules/agents.RandomAgent/0.7/experi...
# 71                                                  None
# 72     results/onerule/agents.CorrectingAgent/0.7/exp...
# 73     results/onerule/agents.CorrectingAgent/0.7/exp...
# 74                                                  None
# 75                                                  None
# 76     results/bijection/agents.CorrectingAgent/0.7/e...
# 77     results/bijection/agents.CorrectingAgent/0.7/e...
# 78     results/maroon/agents.CorrectingAgent/0.7/expe...
# 79     results/maroon/agents.CorrectingAgent/0.7/expe...
# 80     results/maroon/agents.RandomAgent/0.7/experime...
# 81     results/bijection/agents.RandomAgent/0.7/exper...
# 82                                                  None
# 83                                                  None
# 84                                                  None
# 85                                                  None
# 86                                                  None
# 87                                                  None
# 88     results/onerule/agents.CorrectingAgent/0.7/exp...
# 89     results/onerule/agents.CorrectingAgent/0.7/exp...
# 90                                                  None
# 91     results/onerule/agents.CorrectingAgent/0.7/exp...
# 92     results/tworules/agents.CorrectingAgent/0.7/ex...
# 93     results/tworules/agents.CorrectingAgent/0.7/ex...
# 94     results/maroon/agents.CorrectingAgent/0.7/expe...
# 95     results/maroon/agents.CorrectingAgent/0.7/expe...
# 96     results/bijection/agents.CorrectingAgent/0.7/e...
# 97     results/bijection/agents.CorrectingAgent/0.7/e...
# 98                                                  None
# 99     results/onerule/agents.CorrectingAgent/0.7/exp...
# 100    results/tworules/agents.CorrectingAgent/0.7/ex...
# 101    results/tworules/agents.CorrectingAgent/0.7/ex...
# 102    results/maroon/agents.CorrectingAgent/0.7/expe...
# 103    results/maroon/agents.CorrectingAgent/0.7/expe...
# 104    results/bijection/agents.CorrectingAgent/0.7/e...
# 105    results/bijection/agents.CorrectingAgent/0.7/e...
# 106                                                 None
# 107    results/onerule/agents.CorrectingAgent/0.7/exp...
# 108                                                 None
# 109                                                 None
# 110                                                 None
# 111                                                 None
# 112                                                 None
# 113    results/tworules/agents.CorrectingAgent/0.7/ex...
# 114    results/tworules/agents.CorrectingAgent/0.7/ex...
# 115    results/maroon/agents.CorrectingAgent/0.7/expe...
# 116    results/maroon/agents.CorrectingAgent/0.7/expe...
# 117    results/bijection/agents.CorrectingAgent/0.7/e...
# 118    results/bijection/agents.CorrectingAgent/0.7/e...
# 119    results/onerule/agents.CorrectingAgent/0.7/exp...
# 120    results/onerule/agents.CorrectingAgent/0.7/exp...
# 121    results/bijection/agents.CorrectingAgent/0.7/e...
# 122    results/bijection/agents.CorrectingAgent/0.7/e...
# 123    results/maroon/agents.CorrectingAgent/0.7/expe...
# 124    results/maroon/agents.CorrectingAgent/0.7/expe...
# 125    results/tworules/agents.CorrectingAgent/0.7/ex...
# 126    results/tworules/agents.CorrectingAgent/0.7/ex...
# 127    results/tworules/agents.CorrectingAgent/0.7/ex...
# 128    results/maroon/agents.CorrectingAgent/0.7/expe...
# 129    results/bijection/agents.CorrectingAgent/0.7/e...
# 130    results/onerule/agents.CorrectingAgent/0.7/exp...
# 131    results/onerule/agents.CorrectingAgent/0.7/exp...
# 132    results/bijection/agents.CorrectingAgent/0.7/e...
# 133    results/maroon/agents.CorrectingAgent/0.7/expe...
# 134    results/tworules/agents.CorrectingAgent/0.7/ex...
# 135    results/tworules/agents.CorrectingAgent/0.7/ex...
# 136    results/tworules/agents.CorrectingAgent/0.7/ex...
# 137                                                 None
# 138    results/onerule/agents.CorrectingAgent/0.7/exp...
# 139    results/onerule/agents.CorrectingAgent/0.7/exp...
# 140    results/tworules/agents.CorrectingAgent/0.7/ex...
# 141                                                 None
# 142                                                 None
# 143                                                 None
# 144                                                 None
# 145                                                 None
# 146                                                 None
# 147                                                 None
# 148                                                 None
# 149                                                 None
# 150    results/simplecolours/agents.NoLanguageAgent/0...
# 151    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 152    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 153    results/simplecolours/agents.NoLanguageAgent/0...
# 154                                                 None
# 155                                                 None
# 156    results/simplecolours/agents.NoLanguageAgent/0...
# 157                                                 None
# 158    results/simplecolours/agents.NoLanguageAgent/0...
# 159    results/simplecolours/agents.NoLanguageAgent/0...
# 160    results/simplecolours/agents.NoLanguageAgent/0...
# 161    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 162    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 163                                                 None
# 164                                                 None
# 165    results/onerule/agents.CorrectingAgent/0.7/exp...
# 166    results/tworules/agents.CorrectingAgent/0.7/ex...
# 167    results/maroon/agents.CorrectingAgent/0.7/expe...
# 168    results/bijection/agents.CorrectingAgent/0.7/e...
# 169    results/simplecolours/agents.CorrectingAgent/0...
# 170                                                 None
# 171                                                 None
# 172                                                 None
# 173    results/simplecolours/agents.CorrectingAgent/0...
# 174                                                 None
# 175    results/simplecolours/agents.CorrectingAgent/0...
# 176                                                 None
# 177    results/simplecolours/agents.CorrectingAgent/0...
# 178    results/onerule/agents.CorrectingAgent/0.7/exp...
# 179    results/tworules/agents.CorrectingAgent/0.7/ex...
# 180    results/maroon/agents.CorrectingAgent/0.7/expe...
# 181    results/bijection/agents.CorrectingAgent/0.7/e...
# 182                                                 None
# 183                                                 None
# 184                                                 None
# 185    results/simplecolours/agents.NoLanguageAgent/0...
# 186    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 187                                                 None
# 188                                                 None
# 189                                                 None
# 190    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 191    results/bijection/agents.NoLanguageAgent/0.7/e...
# 192    results/maroon/agents.NoLanguageAgent/0.7/expe...
# 193                                                 None
# 194    results/onerule/agents.CorrectingAgent/0.7/exp...
# 195    results/tworules/agents.CorrectingAgent/0.7/ex...
# 196    results/maroon/agents.CorrectingAgent/0.7/expe...
# 197    results/bijection/agents.CorrectingAgent/0.7/e...
# 198    results/simplecolours/agents.CorrectingAgent/0...
# 199    results/simplecolours/agents.CorrectingAgent/0...
# 200    results/onerule/agents.CorrectingAgent/0.7/exp...
# 201    results/tworules/agents.CorrectingAgent/0.7/ex...
# 202    results/maroon/agents.CorrectingAgent/0.7/expe...
# 203    results/bijection/agents.CorrectingAgent/0.7/e...
# 204    results/simplecolours/agents.CorrectingAgent/0...
# 205    results/onerule/agents.CorrectingAgent/0.7/exp...
# 206    results/tworules/agents.CorrectingAgent/0.7/ex...
# 207    results/maroon/agents.CorrectingAgent/0.7/expe...
# 208    results/bijection/agents.CorrectingAgent/0.7/e...
# 209    results/simplecolours/agents.CorrectingAgent/0...
# 210    results/onerule/agents.CorrectingAgent/0.7/exp...
# 211    results/tworules/agents.CorrectingAgent/0.7/ex...
# 212    results/maroon/agents.CorrectingAgent/0.7/expe...
# 213    results/bijection/agents.CorrectingAgent/0.7/e...
# 214                                                 None
# 215    results/simplecolours/agents.CorrectingAgent/0...
# 216    results/onerule/agents.CorrectingAgent/0.7/exp...
# 217    results/tworules/agents.CorrectingAgent/0.7/ex...
# 218    results/maroon/agents.CorrectingAgent/0.7/expe...
# 219    results/bijection/agents.CorrectingAgent/0.7/e...
# 220    results/simplecolours/agents.CorrectingAgent/0...
# 221    results/onerule/agents.CorrectingAgent/0.7/exp...
# 222    results/tworules/agents.CorrectingAgent/0.7/ex...
# 223    results/maroon/agents.CorrectingAgent/0.7/expe...
# 224    results/bijection/agents.CorrectingAgent/0.7/e...
# 225    results/onerule/agents.CorrectingAgent/0.7/exp...
# 226    results/tworules/agents.CorrectingAgent/0.7/ex...
# 227    results/maroon/agents.CorrectingAgent/0.7/expe...
# 228    results/bijection/agents.CorrectingAgent/0.7/e...
# 229    results/simplecolours/agents.CorrectingAgent/0...
# 230    results/onerule/agents.CorrectingAgent/0.7/exp...
# 231    results/tworules/agents.CorrectingAgent/0.7/ex...
# 232    results/maroon/agents.CorrectingAgent/0.7/expe...
# 233    results/bijection/agents.CorrectingAgent/0.7/e...
# 234    results/simplecolours/agents.CorrectingAgent/0...
# 235    results/simplecolours/agents.RandomAgent/0.7/e...
# 236    results/onerule/agents.RandomAgent/0.7/experim...
# 237    results/tworules/agents.RandomAgent/0.7/experi...
# 238    results/maroon/agents.RandomAgent/0.7/experime...
# 239    results/bijection/agents.RandomAgent/0.7/exper...
# 240                                                 None
# 241    results/triplicatered200/agents.CorrectingAgen...
# 242    results/triplicatered200/agents.CorrectingAgen...
# 243    results/triplicatered200/agents.CorrectingAgen...
# 244    results/triplicatered200/agents.RandomAgent/0....
# 245                                                 None
# 246    results/triplicatered200/agents.PerfectColours...
# 247    results/duplicatered/agents.CorrectingAgent/0....
# 248    results/duplicatered/agents.CorrectingAgent/0....
# 249    results/duplicatered/agents.CorrectingAgent/0....
# 250    results/duplicatered/agents.RandomAgent/0.7/ex...
# 251    results/duplicatered/agents.PerfectColoursAgen...
# 252    results/simplecolours/agents.PerfectColoursAge...
# 253    results/onerule/agents.PerfectColoursAgent/0.7...
# 254    results/tworules/agents.PerfectColoursAgent/0....
# 255    results/maroon/agents.PerfectColoursAgent/0.7/...
# 256    results/bijection/agents.PerfectColoursAgent/0...
# 257    results/simplecolours/agents.NoLanguageAgent/0...
# 258    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 259    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 260    results/bijection/agents.NoLanguageAgent/0.7/e...
# 261    results/maroon/agents.NoLanguageAgent/0.7/expe...
# 262                                                 None
# 263                                                 None
# 264    results/duplicatered/agents.NoLanguageAgent/0....
# 265                                                 None
# 266                                                 None
# 267    results/triplicatered/agents.CorrectingAgent/0...
# 268    results/triplicatered/agents.CorrectingAgent/0...
# 269    results/triplicatered/agents.CorrectingAgent/0...
# 270    results/triplicatered/agents.RandomAgent/0.7/e...
# 271    results/triplicatered/agents.PerfectColoursAge...
# 272                                                 None
# 273                                                 None
# 274                                                 None
# 275                                                 None
# 276                                                 None
# 277                                                 None
# 278                                                 None
# 279                                                 None
# 280    results/tworules200/agents.CorrectingAgent/0.7...
# 281    results/tworules200/agents.CorrectingAgent/0.7...
# 282    results/tworules200/agents.CorrectingAgent/0.7...
# 283    results/tworules200/agents.RandomAgent/0.7/exp...
# 284                                                 None
# 285                                                 None
# 286                                                 None
# 287    results/triplicatered/agents.NoLanguageAgent/0...
# 288                                                 None
# 289                                                 None
# 290    results/triplicatered/agents.NoLanguageAgent/0...
# 291    results/tworules200/agents.NoLanguageAgent/0.7...
# 292    results/tworules2/agents.NoLanguageAgent/0.7/e...
# 293    results/tworules2/agents.CorrectingAgent/0.7/e...
# 294    results/tworules2/agents.RandomAgent/0.7/exper...
# 295                                                 None
# 296                                                 None
# 297                                                 None
# 298                                                 None
# 299    results/tworules2/agents.CorrectingAgent/0.7/e...
# 300    results/threerules/agents.NoLanguageAgent/0.7/...
# 301    results/threerules/agents.CorrectingAgent/0.7/...
# 302    results/threerules/agents.RandomAgent/0.7/expe...
# 303                                                 None
# 304                                                 None
# 305                                                 None
# 306                                                 None
# 307                                                 None
# 308                                                 None
# 309    results/threerules/agents.CorrectingAgent/0.7/...
# 310                                                 None
#
#                 neural_config   status
# index
# 0                        None     None
# 1                     DEFAULT     done
# 2                 adam_lr:0.1     done
# 3                   adam_lr:1     done
# 4        nesterov_lr:0.1mom:0     done
# 5      nesterov_lr:0.1mom:0.4     done
# 6                        None     done
# 7                        None     done
# 8                        None     done
# 9                        None     done
# 10                       None     done
# 11                       None     done
# 12                       None     done
# 13                       None     done
# 14                       None  running
# 15                       None     done
# 16                       None     done
# 17                       None  running
# 18                       None     done
# 19                       None  running
# 20                       None  running
# 21                       None     done
# 22                       None     done
# 23                       None  running
# 24                       None     done
# 25                       None     done
# 26                       None  running
# 27                       None  running
# 28                       None  running
# 29                       None  running
# 30                       None  running
# 31                       None  running
# 32                       None  running
# 33                       None  running
# 34                       None  running
# 35                       None     done
# 36                       None  running
# 37                       None  running
# 38                       None     done
# 39                       None     done
# 40                       None     done
# 41                       None     done
# 42                       None  running
# 43                       None  running
# 44                       None  running
# 45                       None  running
# 46                       None  running
# 47                       None  running
# 48                       None  running
# 49                       None  running
# 50                       None  running
# 51                       None  running
# 52                       None  running
# 53                       None     done
# 54                       None     done
# 55                       None     done
# 56                       None  running
# 57                       None  running
# 58                       None     done
# 59                       None  running
# 60                       None     done
# 61                       None     done
# 62                       None     done
# 63                       None     done
# 64                       None     done
# 65                       None  running
# 66                       None     done
# 67                       None     done
# 68                       None     done
# 69                       None     done
# 70                       None     done
# 71                       None  running
# 72                       None     done
# 73                       None     done
# 74                       None  running
# 75                       None  running
# 76                       None     done
# 77                       None     done
# 78                       None     done
# 79                       None     done
# 80                       None     done
# 81                       None     done
# 82                    DEFAULT  running
# 83                    DEFAULT  running
# 84                    DEFAULT  running
# 85                    DEFAULT  running
# 86                    DEFAULT  running
# 87                    DEFAULT  running
# 88                    DEFAULT     done
# 89                 3d_default     done
# 90                 3d_default  running
# 91                 3d_default     done
# 92                 3d_default     done
# 93                 3d_default     done
# 94                 3d_default     done
# 95                 3d_default     done
# 96                 3d_default     done
# 97                 3d_default     done
# 98                       None  running
# 99                   fixed_bw     done
# 100                  fixed_bw     done
# 101                  fixed_bw     done
# 102                  fixed_bw     done
# 103                  fixed_bw     done
# 104                  fixed_bw     done
# 105                  fixed_bw     done
# 106                      None  running
# 107                  fixed_bw     done
# 108                  fixed_bw  running
# 109                  fixed_bw  running
# 110                  fixed_bw  running
# 111                  fixed_bw  running
# 112                  fixed_bw  running
# 113                  fixed_bw     done
# 114                  fixed_bw     done
# 115                  fixed_bw     done
# 116                  fixed_bw     done
# 117                  fixed_bw     done
# 118                  fixed_bw     done
# 119                      None     done
# 120                      None     done
# 121                      None     done
# 122                      None     done
# 123                      None     done
# 124                      None     done
# 125                      None     done
# 126                      None     done
# 127                  fixed_bw     done
# 128                  fixed_bw     done
# 129                  fixed_bw     done
# 130                  fixed_bw     done
# 131                      None     done
# 132                      None     done
# 133                      None     done
# 134                      None     done
# 135                  fixed_bw     done
# 136                  fixed_bw     done
# 137                  fixed_bw  running
# 138                  fixed_bw     done
# 139              fixed_bw_0.2     done
# 140                  fixed_bw     done
# 141                  fixed_bw  running
# 142                  fixed_bw  running
# 143                  fixed_bw  running
# 144                  fixed_bw  running
# 145                  fixed_bw  running
# 146                  fixed_bw  running
# 147                  fixed_bw  running
# 148                  fixed_bw  running
# 149                  fixed_bw  running
# 150                  fixed_bw     done
# 151                  fixed_bw     done
# 152                  fixed_bw     done
# 153                  fixed_bw     done
# 154                  fixed_bw  running
# 155                  fixed_bw  running
# 156                  fixed_bw     done
# 157                  fixed_bw  running
# 158                  fixed_bw     done
# 159                  fixed_bw     done
# 160                  fixed_bw     done
# 161                  fixed_bw     done
# 162                  fixed_bw     done
# 163              fixed_bw_0.2  running
# 164              fixed_bw_0.2  running
# 165              fixed_bw_0.2     done
# 166              fixed_bw_0.2     done
# 167              fixed_bw_0.2     done
# 168              fixed_bw_0.2     done
# 169              fixed_bw_0.2     done
# 170                      None  running
# 171                      None  running
# 172                      None  running
# 173                      None     done
# 174                      None  running
# 175                      None     done
# 176                      None  running
# 177                      None     done
# 178                      None     done
# 179                      None     done
# 180                      None     done
# 181                      None     done
# 182                  fixed_bw  running
# 183                  fixed_bw  running
# 184                  fixed_bw  running
# 185                  fixed_bw     done
# 186                  fixed_bw     done
# 187                  fixed_bw  running
# 188                  fixed_bw  running
# 189                  fixed_bw  running
# 190                  fixed_bw     done
# 191                  fixed_bw     done
# 192                  fixed_bw     done
# 193              fixed_bw_0.2  running
# 194              fixed_bw_0.2     done
# 195              fixed_bw_0.2     done
# 196              fixed_bw_0.2     done
# 197              fixed_bw_0.2     done
# 198              fixed_bw_0.2     done
# 199                      None     done
# 200                      None     done
# 201                      None     done
# 202                      None     done
# 203                      None     done
# 204                   DEFAULT     done
# 205                   DEFAULT     done
# 206                   DEFAULT     done
# 207                   DEFAULT     done
# 208                   DEFAULT     done
# 209                   DEFAULT     done
# 210                   DEFAULT     done
# 211                   DEFAULT     done
# 212                   DEFAULT     done
# 213                   DEFAULT     done
# 214                   DEFAULT  running
# 215                   DEFAULT     done
# 216                   DEFAULT     done
# 217                   DEFAULT     done
# 218                   DEFAULT     done
# 219                   DEFAULT     done
# 220                      None     done
# 221                      None     done
# 222                      None     done
# 223                      None     done
# 224                      None     done
# 225                  fixed_bw     done
# 226                  fixed_bw     done
# 227                  fixed_bw     done
# 228                  fixed_bw     done
# 229                  fixed_bw     done
# 230              fixed_bw_0.2     done
# 231              fixed_bw_0.2     done
# 232              fixed_bw_0.2     done
# 233              fixed_bw_0.2     done
# 234              fixed_bw_0.2     done
# 235                      None     done
# 236                      None     done
# 237                      None     done
# 238                      None     done
# 239                      None     done
# 240              fixed_bw_0.2  running
# 241                  fixed_bw     done
# 242                  fixed_bw     done
# 243                      None     done
# 244                      None     done
# 245                      None  running
# 246                      None     done
# 247              fixed_bw_0.2     done
# 248                  fixed_bw     done
# 249                      None     done
# 250                      None     done
# 251                      None     done
# 252                      None     done
# 253                      None     done
# 254                      None     done
# 255                      None     done
# 256                      None     done
# 257                  fixed_bw     done
# 258                  fixed_bw     done
# 259                  fixed_bw     done
# 260                  fixed_bw     done
# 261                  fixed_bw     done
# 262                  fixed_bw  running
# 263                  fixed_bw  running
# 264                  fixed_bw     done
# 265                  fixed_bw  running
# 266              fixed_bw_0.2  running
# 267              fixed_bw_0.2     done
# 268                  fixed_bw     done
# 269                      None     done
# 270                      None     done
# 271                      None     done
# 272                      None  running
# 273                      None  running
# 274                      None  running
# 275              fixed_bw_0.2  running
# 276                  fixed_bw  running
# 277              fixed_bw_0.2  running
# 278              fixed_bw_0.2  running
# 279              fixed_bw_0.2  running
# 280              fixed_bw_0.2     done
# 281                  fixed_bw     done
# 282                      None     done
# 283                      None     done
# 284                      None  running
# 285                      None  running
# 286                      None  running
# 287                      None     done
# 288                      None  running
# 289                      None  running
# 290                  fixed_bw     done
# 291                  fixed_bw     done
# 292                  fixed_bw     done
# 293                  fixed_bw     done
# 294                      None     done
# 295                  fixed_bw  running
# 296                  fixed_bw  running
# 297                  fixed_bw  running
# 298                  fixed_bw  running
# 299                  fixed_bw     done
# 300                  fixed_bw     done
# 301                  fixed_bw     done
# 302                      None     done
# 303                  fixed_bw  running
# 304                  fixed_bw  running
# 305                  fixed_bw  running
# 306                  fixed_bw  running
# 307                  fixed_bw  running
# 308                  fixed_bw  running
# 309                  fixed_bw     done
# 310                  fixed_bw  running

# %%
exp = load_experiments([309, 300], 'threerules')
exp.plot(labels=labels, dataset_label='Three Rules')

# %%
exp = load_experiments([194, 186], 'onerule')
exp.plot(labels=labels, dataset_label='One Rule')

# %%
exp = load_experiments([292, 299], 'tworules2')
exp.plot(labels=labels, dataset_label='Two Rules')

# %%
exp.results_files
# Out:
# {'agents.CorrectingAgent_0': <evaluation.ResultsFile at 0x7f49fd13de10>,
#  'agents.NoLanguageAgent_0': <evaluation.ResultsFile at 0x7f49feab5550>,
#  'agents.RandomAgent_0': <evaluation.ResultsFile at 0x7f49fcecb668>}

# %%
a = exp.get_agent('agents.CorrectingAgent_0')
corr_models = list(a.rule_models.values())
print(corr_models)
table_1 = corr_models[0]
table_2 = corr_models[1]
table_3 = corr_models[3]
# Out:
# [<prob_model.CorrectionModel object at 0x7f49fd020c18>, <prob_model.CorrectionModel object at 0x7f49fcff77b8>, <prob_model.TableCorrectionModel object at 0x7f49fd005208>, <prob_model.CorrectionModel object at 0x7f49fd005c88>, <prob_model.TableCorrectionModel object at 0x7f49fd00f208>, <prob_model.TableCorrectionModel object at 0x7f49fd00fc50>]

# %%
rb = table_3.rule_belief
rb.belief
# Out:
# array([[1.00000000e+00, 1.73886231e-29],
#        [2.22044605e-16, 0.00000000e+00]])

# %%
print(a.goal.asPDDL())
# Out:
# (and (forall (?x) (in-tower ?x)) (forall (?x) (or (not (purple ?x)) (exists (?y) (and (orange ?y) (on ?x ?y))))) (forall (?x) (or (not (red ?x)) (exists (?y) (and (blue ?y) (on ?x ?y))))) (forall (?x) (or (not (green ?x)) (exists (?y) (and (yellow ?y) (on ?x ?y))))) (forall (?y) (or (not (yellow ?y)) (exists (?x) (and (green ?x) (on ?x ?y))))))

# %%
exp = load_experiments([267, 290], 'triplicatered')
exp.plot(labels=labels, dataset_label='Three Red')

# %%
exp = load_experiments([247, 264], 'duplicatered')
exp.show_results(labels=labels)
# Out:
# Lingustic -22.0
# No Language -42.0
# Naive -65.0

# %%
exp = load_experiments([242, 242], 'triplicatered200')
exp.show_results(labels=labels)
# Out:
# Lingustic 0.0
# No Language 0.0
# Naive -71.0

# %%
exp = load_experiments([227, 261], 'maroon')
exp.plot(labels=labels, dataset_label='Maroon')

# %%
list(exp.test_colour_models('agents.CorrectingAgent_0', draw=True))
list(exp.test_colour_models('agents.CorrectingAgent_1', draw=True))
# Out:
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# True Label  B=1 B=0
# Predict B=1| 9 | 10 |
#         B=0| 0 | 23 |
# True Label  G=1 G=0
# Predict G=1| 10 | 13 |
#         G=0| 0 | 19 |
# True Label  M=1 M=0
# Predict M=1| 0 | 38 |
#         M=0| 0 | 4 |
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# True Label  B=1 B=0
# Predict B=1| 8 | 2 |
#         B=0| 1 | 31 |
# True Label  G=1 G=0
# Predict G=1| 7 | 0 |
#         G=0| 3 | 32 |
# True Label  M=1 M=0
# Predict M=1| 0 | 9 |
#         M=0| 0 | 33 |
# [('red', {'fn': 0, 'fp': 0, 'tn': 37, 'tp': 5}),
#  ('blue', {'fn': 1, 'fp': 2, 'tn': 31, 'tp': 8}),
#  ('green', {'fn': 3, 'fp': 0, 'tn': 32, 'tp': 7}),
#  ('maroon', {'fn': 0, 'fp': 9, 'tn': 33, 'tp': 0})]

# %%
exp = load_experiments([226, 259], 'tworules')
exp.show_results(labels=labels)
# Out:
# Language -20.0
# No Language -30.0
# Naive -64.0

# %%
list(exp.test_colour_models('agents.CorrectingAgent_0', draw=True))
list(exp.test_colour_models('agents.CorrectingAgent_1', draw=True))
# Out:
# True Label  G=1 G=0
# Predict G=1| 8 | 14 |
#         G=0| 2 | 18 |
# True Label  Y=1 Y=0
# Predict Y=1| 3 | 4 |
#         Y=0| 0 | 35 |
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# True Label  B=1 B=0
# Predict B=1| 9 | 2 |
#         B=0| 0 | 31 |
# True Label  G=1 G=0
# Predict G=1| 9 | 6 |
#         G=0| 1 | 26 |
# True Label  Y=1 Y=0
# Predict Y=1| 3 | 3 |
#         Y=0| 0 | 36 |
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# True Label  B=1 B=0
# Predict B=1| 8 | 3 |
#         B=0| 1 | 30 |
# [('green', {'fn': 1, 'fp': 6, 'tn': 26, 'tp': 9}),
#  ('yellow', {'fn': 0, 'fp': 3, 'tn': 36, 'tp': 3}),
#  ('red', {'fn': 0, 'fp': 0, 'tn': 37, 'tp': 5}),
#  ('blue', {'fn': 1, 'fp': 3, 'tn': 30, 'tp': 8})]

# %%
exp = load_experiments([221, 230, 258], 'onerule')
exp.show_results(labels=labels)
# Out:
# Lingustic+Gaussian -1.0
# Lingustic+KDE -3.0
# No Language -22.0
# Naive -36.0

# %%
exp.results_files
# Out:
# {'agents.CorrectingAgent_0': <evaluation.ResultsFile at 0x7f5220093978>,
#  'agents.CorrectingAgent_1': <evaluation.ResultsFile at 0x7f52200937f0>,
#  'agents.NoLanguageAgent_0': <evaluation.ResultsFile at 0x7f52200aef98>,
#  'agents.RandomAgent_0': <evaluation.ResultsFile at 0x7f52201f5f98>}

# %%
exp.print_colour_models('agents.CorrectingAgent_0')
exp.print_colour_models('agents.CorrectingAgent_1')
# Out:
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# red {'tp': 5, 'fp': 0, 'fn': 0, 'tn': 37}
# True Label  B=1 B=0
# Predict B=1| 9 | 1 |
#         B=0| 0 | 32 |
# blue {'tp': 9, 'fp': 1, 'fn': 0, 'tn': 32}
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# red {'tp': 5, 'fp': 0, 'fn': 0, 'tn': 37}
# True Label  B=1 B=0
# Predict B=1| 9 | 3 |
#         B=0| 0 | 30 |
# blue {'tp': 9, 'fp': 3, 'fn': 0, 'tn': 30}

# %%
exp = load_experiments([220, 234, 257], 'simple')
# exp.plot(labels=labels)
# exp.print_test(labels=labels)
exp.show_results(labels)
# Out:
# Lingustic+Gaussian 0.0
# Lingustic+KDE -43.0
# No Language 0.0
# Naive -50.0

# %%
df = exp.to_test_df()
labels = ['Lingustic+Gaussian', 'Lingustic+KDE', 'No Language', 'Naive']
columns = list(filter(lambda x: 'cumsum' in x, df.columns))
for l, c in zip(labels, columns):
    a = df[c].tail(1)
    print(l, a.values[0])
# Out:
# Lingustic+Gaussian 0.0
# Lingustic+KDE -43.0
# No Language 0.0
# Naive -50.0

# %%
a.values[0]
# Out:
# -50.0

# %%
exp = load_experiments([200, 194, 186], 'onerule')
exp.plot(labels=['Lingustic+Gaussian', 'Lingustic+KDE', 'No Language', 'Naive'])

# %%
exp = load_experiments([ 201, 195, 190], 'tworules')
exp.plot(labels=['Lingustic+Gaussian', 'Lingustic+KDE', 'No Language', 'Naive'])

# %%
exp = load_experiments([ 202, 196, 192], 'maroon')
exp.plot(labels=['Lingustic+Gaussian', 'Lingustic+KDE', 'No Language', 'Naive'])

# %%
exp = load_experiments([ 203, 197, 191], 'bijection')
exp.plot(labels=['Lingustic+Gaussian', 'Lingustic+KDE', 'No Language', 'Naive'])

# %%
exp = load_experiments([181, 168, 191], 'bijection')
exp.plot(labels=['Lingustic+Gaussian', 'Lingustic+KDE', 'No Language', 'Naive'])

# %%
exp = load_experiments([177, 169, 186], 'simple')
exp.plot(labels=['gaussian', 'kde', 'no-language', 'naive'])

# %%
exp = load_experiments([107, 120, 130, 131,  138, 139, 161], 'onerule')
exp.plot(labels=['kde w/ search', 'gaussian w/ search & negative', 
                 'kde w/ search fixed', 'gaussian search fixed', 'kde nocorr', 
                 'kde 0.2', 'nolanguage', 'naive'])

# %%
exp = load_experiments([131, 130, 161], 'onerule')
exp.plot(labels=['gaussian', 'kde', 'nolanguage', 'naive'])

# %%
exp = load_experiments([ 127, 134, 162], 'tworules')
exp.plot(labels=['kde search fixed', 
                 'gaussian search fixed', 
                 'nolanguage', 'Naive'])

# %%
exp = load_experiments([ 127, 134, 162], 'tworules')
exp.plot(labels=['kde search fixed', 
                 'gaussian search fixed', 
                 'nolanguage', 'Naive'])
