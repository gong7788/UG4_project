# %%
from correctingagent.experiments.experiment import add_experiment
from correctingagent.experiments.experiment_tracking import read_experiments, get_results_file, get_baseline, load_experiments
from correctingagent.experiments.evaluation import test_colour_model, colour_probs, colour_dict, name_to_rgb
from correctingagent.util.util import add_config_option, create_experiment



# %matplotlib inline

# %%
read_experiments()
# Out:
#                                    config_name  \
# index
# 0                                         None
# 1                                simple_neural
# 2                           neural_onerule5000
# 3                           neural_onerule5000
# 4                           neural_onerule5000
# 5                           neural_onerule5000
# 6                                     tworules
# 7                           tworules_no_update
# 8                                     tworules
# 9                           tworules_no_update
# 10                                    tworules
# 11                                     onerule
# 12                     onerule_update_negative
# 13                                    tworules
# 14                    tworules_update_negative
# 15                     tworules_perfect_colour
# 16                 tworules_perfect_colour_vis
# 17                     tworules_perfect_colour
# 18                                    tworules
# 19                    tworules_update_negative
# 20                                    tworules
# 21                                    tworules
# 22                    tworules_update_negative
# 23                        tworules_update_once
# 24                        tworules_update_once
# 25          tworules_update_once_with_negative
# 26                                    tworules
# 27                                    tworules
# 28                                    tworules
# 29                                    tworules
# ...                                        ...
# 145                          simple_nolanguage
# 146                          simple_nolanguage
# 147                          simple_nolanguage
# 148                          simple_nolanguage
# 149                          simple_nolanguage
# 150                          simple_nolanguage
# 151                         onerule_nolanguage
# 152                        tworules_nolanguage
# 153                          simple_nolanguage
# 154                          simple_nolanguage
# 155                          simple_nolanguage
# 156                          simple_nolanguage
# 157                          simple_nolanguage
# 158                          simple_nolanguage
# 159                          simple_nolanguage
# 160                          simple_nolanguage
# 161                         onerule_nolanguage
# 162                        tworules_nolanguage
# 163                                onerule_kde
# 164                                onerule_kde
# 165                                onerule_kde
# 166                               tworules_kde
# 167                                 maroon_kde
# 168                              bijection_kde
# 169                                 simple_kde
# 170           simple_update_once_with_negative
# 171    simplecolours_update_once_with_negative
# 172    simplecolours_update_once_with_negative
# 173           simple_update_once_with_negative
# 174          onerule_update_once_with_negative
#
#                                          experiment_file  \
# index
# 0                                                   None
# 1      results/simplecolours/agents.NeuralCorrectingA...
# 2      results/onerule5000/agents.NeuralCorrectingAge...
# 3      results/onerule5000/agents.NeuralCorrectingAge...
# 4      results/onerule5000/agents.NeuralCorrectingAge...
# 5      results/onerule5000/agents.NeuralCorrectingAge...
# 6      results/tworules/agents.CorrectingAgent/0.7/ex...
# 7      results/tworules/agents.CorrectingAgent/0.7/ex...
# 8      results/tworules/agents.CorrectingAgent/0.7/ex...
# 9      results/tworules/agents.CorrectingAgent/0.7/ex...
# 10     results/tworules/agents.CorrectingAgent/0.7/ex...
# 11     results/onerule/agents.CorrectingAgent/0.7/exp...
# 12     results/onerule/agents.CorrectingAgent/0.7/exp...
# 13     results/tworules/agents.CorrectingAgent/0.7/ex...
# 14                                                  None
# 15     results/tworules/agents.PerfectColoursAgent/0....
# 16     results/tworules/agents.PerfectColoursAgent/0....
# 17                                                  None
# 18     results/tworules/agents.CorrectingAgent/0.7/ex...
# 19                                                  None
# 20                                                  None
# 21     results/tworules/agents.CorrectingAgent/0.7/ex...
# 22     results/tworules/agents.CorrectingAgent/0.7/ex...
# 23                                                  None
# 24     results/tworules/agents.CorrectingAgent/0.7/ex...
# 25     results/tworules/agents.CorrectingAgent/0.7/ex...
# 26                                                  None
# 27                                                  None
# 28                                                  None
# 29                                                  None
# ...                                                  ...
# 145                                                 None
# 146                                                 None
# 147                                                 None
# 148                                                 None
# 149                                                 None
# 150    results/simplecolours/agents.NoLanguageAgent/0...
# 151    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 152    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 153    results/simplecolours/agents.NoLanguageAgent/0...
# 154                                                 None
# 155                                                 None
# 156    results/simplecolours/agents.NoLanguageAgent/0...
# 157                                                 None
# 158    results/simplecolours/agents.NoLanguageAgent/0...
# 159    results/simplecolours/agents.NoLanguageAgent/0...
# 160    results/simplecolours/agents.NoLanguageAgent/0...
# 161    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 162    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 163                                                 None
# 164                                                 None
# 165    results/onerule/agents.CorrectingAgent/0.7/exp...
# 166    results/tworules/agents.CorrectingAgent/0.7/ex...
# 167    results/maroon/agents.CorrectingAgent/0.7/expe...
# 168    results/bijection/agents.CorrectingAgent/0.7/e...
# 169    results/simplecolours/agents.CorrectingAgent/0...
# 170                                                 None
# 171                                                 None
# 172                                                 None
# 173    results/simplecolours/agents.CorrectingAgent/0...
# 174                                                 None
#
#                 neural_config   status
# index
# 0                        None     None
# 1                     DEFAULT     done
# 2                 adam_lr:0.1     done
# 3                   adam_lr:1     done
# 4        nesterov_lr:0.1mom:0     done
# 5      nesterov_lr:0.1mom:0.4     done
# 6                        None     done
# 7                        None     done
# 8                        None     done
# 9                        None     done
# 10                       None     done
# 11                       None     done
# 12                       None     done
# 13                       None     done
# 14                       None  running
# 15                       None     done
# 16                       None     done
# 17                       None  running
# 18                       None     done
# 19                       None  running
# 20                       None  running
# 21                       None     done
# 22                       None     done
# 23                       None  running
# 24                       None     done
# 25                       None     done
# 26                       None  running
# 27                       None  running
# 28                       None  running
# 29                       None  running
# ...                       ...      ...
# 145                  fixed_bw  running
# 146                  fixed_bw  running
# 147                  fixed_bw  running
# 148                  fixed_bw  running
# 149                  fixed_bw  running
# 150                  fixed_bw     done
# 151                  fixed_bw     done
# 152                  fixed_bw     done
# 153                  fixed_bw     done
# 154                  fixed_bw  running
# 155                  fixed_bw  running
# 156                  fixed_bw     done
# 157                  fixed_bw  running
# 158                  fixed_bw     done
# 159                  fixed_bw     done
# 160                  fixed_bw     done
# 161                  fixed_bw     done
# 162                  fixed_bw     done
# 163              fixed_bw_0.2  running
# 164              fixed_bw_0.2  running
# 165              fixed_bw_0.2     done
# 166              fixed_bw_0.2     done
# 167              fixed_bw_0.2     done
# 168              fixed_bw_0.2     done
# 169              fixed_bw_0.2     done
# 170                      None  running
# 171                      None  running
# 172                      None  running
# 173                      None     done
# 174                      None  running
#
# [175 rows x 4 columns]

# %%
from os import path

path.relpath('/home/mappelgren/Desktop/correcting-agent/', 'correcting-agent/results/simplecolours/agents.RandomAgent/0.7/experiment4.out')
path.relpath('correcting-agent/results/simplecolours/agents.RandomAgent/0.7/experiment4.out', start='/home/mappelgren/Desktop/correcting-agent/')
path.split('correcting-agent/results/simplecolours/agents.RandomAgent/0.7/experiment4.out')
# name = '/home/mappelgren/Desktop/correcting-agent/results/simplecolours/agents.RandomAgent/0.7/experiment4.out'
# def get_agent_name(result_file):
#     name = result_file.name
#     return [c for c in name.split('/') if 'agents.' in c][0]
# Out:
# ('correcting-agent/results/simplecolours/agents.RandomAgent/0.7',
#  'experiment4.out')

# %%
exp = load_experiments([53, 60,169], 'simple')
exp.plot(labels=['gaussian', 'kde', 'kde_0.5', 'naive'])

# %%
exp = load_experiments([ 127, 134,  166], 'tworules')
exp.plot(labels=[
                 'kde search fixed', 'gaussian search fixed', 
                'kde...', 'Naive'])

# %%
exp = load_experiments([76, 77, 68, 69, 168], 'bijection')
exp.plot(labels=['gaussian', 'gaussian w/ negative', 'kde', 'kde w/ negative', 'kde...',  'naive'])

# %%
exp = load_experiments([131, 130, 165], 'onerule')
exp.plot(labels=['gaussian', 'kde', 'kde...', 'naive'])

# %%
exp = load_experiments([78, 79, 66, 67, 167], 'maroon')
exp.plot(labels=['gaussian', 'gaussian w/ negative', 'kde', 'kde w/ negative', 'kde...', 'naive'])

# %%
exp = load_experiments([53, 60], 'simple')
exp.plot(labels=['gaussian', 'kde', 'naive'])

# %%
#exp = load_experiments([11, 12, 61, 62], 'onerule')
exp = load_experiments([72, 73, 61, 62, 119,  120, 107, 130], 'onerule')
exp.plot(labels=['gaussian', 'gaussian w/ negative', 'kde', 'kde w/ negative', 
                 'gaussian w/ search', 'gaussian w/ search & negative',  'kde w/ search', 
                 'kde w/ search fixed', 'naive'])

# %%
exp = load_experiments([107, 120, 130, 131,  138, 139], 'onerule')
exp.plot(labels=['kde w/ search', 'gaussian w/ search & negative', 
                 'kde w/ search fixed', 'gaussian search fixed', 'kde nocorr', 'kde 0.2', 'naive'])

# %%
exp = load_experiments([131, 130], 'onerule')
exp.plot(labels=['gaussian', 'kde', 'naive'])

# %%
exp.results_files
# Out:
# {'agents.CorrectingAgent_0': <evaluation.ResultsFile at 0x7f878772f588>,
#  'agents.CorrectingAgent_1': <evaluation.ResultsFile at 0x7f878776c588>,
#  'agents.RandomAgent_0': <evaluation.ResultsFile at 0x7f878771d0b8>}

# %%
standard_agent_rf = exp.results_files['agents.CorrectingAgent_0']
kde_agent_rf = exp.results_files['agents.CorrectingAgent_1']
standard_agent = standard_agent_rf.load_agent()
kde_agent = kde_agent_rf.load_agent()

# %%
standard_agent.colour_models
# Out:
# {'blue': <prob_model.ColourModel at 0x7f34f15617f0>,
#  'red': <prob_model.ColourModel at 0x7f34f15614e0>}

# %%
for cm in exp.test_colour_models('agents.CorrectingAgent_0'):
    pass
# Out:
# True Label  R=1 R=0
# Predict R=1| 5 | 1 |
#         R=0| 0 | 36 |
# True Label  B=1 B=0
# Predict B=1| 9 | 3 |
#         B=0| 0 | 30 |

# %%
for cm in standard_agent.colour_models.values():
    test_colour_model(cm)
    cm.draw()
# Out:
# True Label  R=1 R=0
# Predict R=1| 5 | 1 |
#         R=0| 0 | 36 |
# True Label  B=1 B=0
# Predict B=1| 9 | 3 |
#         B=0| 0 | 30 |

# %%
for cm in exp.test_colour_models('agents.CorrectingAgent_1'):
    pass
# Out:
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# True Label  B=1 B=0
# Predict B=1| 8 | 4 |
#         B=0| 1 | 29 |

# %%
for cm in kde_agent.colour_models.values():
    test_colour_model(cm)
    cm.draw()
# Out:
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# True Label  B=1 B=0
# Predict B=1| 8 | 4 |
#         B=0| 1 | 29 |

# %%
red_cm = kde_agent.colour_models['red']
blue_cm = kde_agent.colour_models['blue']

# %%
colour_probs(red_cm )
# Out:
# {'blue': {'blue': 0.002281876810714176,
#   'cornflowerblue': 0.00023490452076325598,
#   'darkblue': 0.019475451912440097,
#   'deepskyblue': 1.9909168843240656e-06,
#   'dodgerblue': 2.8392475101481518e-05,
#   'mediumblue': 0.003653036366166264,
#   'midnightblue': 0.08446438775273457,
#   'navy': 0.03359476398990681,
#   'royalblue': 0.0017086186550483056},
#  'green': {'darkolivegreen': 0.3940258298707034,
#   'forestgreen': 0.010721760846821164,
#   'green': 0.016622626016051113,
#   'greenyellow': 0.0004921078862948446,
#   'lawngreen': 0.0003875842953791002,
#   'limegreen': 0.000560933486191385,
#   'olivedrab': 0.09178987809383062,
#   'palegreen': 1.0592952087310698e-05,
#   'seagreen': 0.007987042828151089,
#   'yellowgreen': 0.006851482791272102},
#  'orange': {'bisque': 4.415826046041213e-06,
#   'darkorange': 0.06319295753059122,
#   'orange': 0.013998222210288035},
#  'pink': {'deeppink': 0.11383792342765967,
#   'fuchsia': 0.021143389642999635,
#   'hotpink': 0.007327613407219992,
#   'lightpink': 5.171467029388196e-05,
#   'magenta': 0.021143389642999635,
#   'pink': 2.95070014429439e-05},
#  'purple': {'blueviolet': 0.06050638527960207,
#   'darkmagenta': 0.32730012342059855,
#   'darkorchid': 0.08075327541368443,
#   'darkviolet': 0.08158625837731685,
#   'indigo': 0.15288413769263992,
#   'purple': 0.4311030085967394},
#  'red': {'crimson': 0.8646093818514553,
#   'darkred': 0.9286327124628252,
#   'firebrick': 0.9255917348614363,
#   'maroon': 0.9205046289341805,
#   'red': 0.8337966079021415},
#  'yellow': {'lightgoldenrodyellow': 1.2022351970289456e-06,
#   'lightyellow': 9.502369642749e-07,
#   'yellow': 0.0001733104388326299}}

# %%
colour_probs(blue_cm ) # miss classifying all of the purples and sea green. 
# All of the red and blue are the highest probability colours, but the purples are too high.
# Out:
# {'blue': {'blue': 0.9629906547705098,
#   'cornflowerblue': 0.8476255191488874,
#   'darkblue': 0.9005035065544369,
#   'deepskyblue': 0.939540804569072,
#   'dodgerblue': 0.9454156308313998,
#   'mediumblue': 0.9514661673889869,
#   'midnightblue': 0.8317985838939157,
#   'navy': 0.8918709640347369,
#   'royalblue': 0.857137480642408},
#  'green': {'darkolivegreen': 0.2448817448943098,
#   'forestgreen': 0.40039826415772733,
#   'green': 0.45374084446169916,
#   'greenyellow': 0.009865927530535319,
#   'lawngreen': 0.01805273751322001,
#   'limegreen': 0.19342530217134626,
#   'olivedrab': 0.20726113370329963,
#   'palegreen': 0.1302404589598932,
#   'seagreen': 0.6656680961881875,
#   'yellowgreen': 0.07657274578712193},
#  'orange': {'bisque': 0.029716534878622452,
#   'darkorange': 0.00761882965232075,
#   'orange': 0.006648708416657918},
#  'pink': {'deeppink': 0.08211281858602698,
#   'fuchsia': 0.19496385749122902,
#   'hotpink': 0.11649792262926356,
#   'lightpink': 0.10253283381282192,
#   'magenta': 0.19496385749122902,
#   'pink': 0.09407741715430333},
#  'purple': {'blueviolet': 0.8067432385640037,
#   'darkmagenta': 0.6180191209999453,
#   'darkorchid': 0.7028554106143121,
#   'darkviolet': 0.7545451766507845,
#   'indigo': 0.6492305860058488,
#   'purple': 0.6303016234812479},
#  'red': {'crimson': 0.025137883992377943,
#   'darkred': 0.12122602045688524,
#   'firebrick': 0.048202643862992195,
#   'maroon': 0.1375638016247786,
#   'red': 0.007131090945617875},
#  'yellow': {'lightgoldenrodyellow': 0.021471006783027307,
#   'lightyellow': 0.02359059518241772,
#   'yellow': 0.0007968084035876679}}

# %%
name_to_rgb('seagreen')
name_to_rgb('blueviolet')
# Out:
# array([0.5411765 , 0.16862746, 0.8862745 ], dtype=float32)

# %%
1/6*1/6*(5/6)**2 * 3*2*1 + 1/6**3*5/6*4 + 1/6**4
# Out:
# 0.13194444444444448

# %%
1-(5/6)**4
# Out:
# 0.5177469135802468

# %%
#exp = load_experiments([40, 41, 63, 64], 'tworules')
exp = load_experiments([41, 63, 64, 126, 125, 113, 114, 127, 134, 135], 'tworules')
exp.plot(labels=['Gaussian', 'KDE without negative update', 'KDE with negative update', 
                 'gaussian w/ search', 'gaussian w/ search & negative', 'KDE w/ search', 
                 'KDE w/ negative & search', 'kde search fixed', 'gaussian search fixed', 
                 'KDE search unfixed', 'Naive'])

# %%
exp = load_experiments([125, 113, 114, 127, 134, 135], 'tworules')
exp.plot(labels=['gaussian w/ search & negative', 'KDE w/ search', 
                 'KDE w/ negative & search', 'kde search fixed', 'gaussian search fixed', 
                 'KDE search unfixed', 'Naive'])

# %%
standard_agent_rf = exp.results_files['agents.CorrectingAgent_0']
kde_agent_rf = exp.results_files['agents.CorrectingAgent_1']
kde_agent_rf_neg = exp.results_files['agents.CorrectingAgent_2']
standard_agent = standard_agent_rf.load_agent()
kde_agent = kde_agent_rf.load_agent()
kde_agent_neg = kde_agent_rf_neg.load_agent()

# %%
standard_agent.colour_models
# Out:
# {'blue': <prob_model.ColourModel at 0x7f34f15617f0>,
#  'red': <prob_model.ColourModel at 0x7f34f15614e0>}

# %%
for cm in standard_agent.colour_models.values():
    test_colour_model(cm)
    cm.draw()
# Out:
# True Label  G=1 G=0
# Predict G=1| 10 | 3 |
#         G=0| 0 | 29 |
# True Label  Y=1 Y=0
# Predict Y=1| 3 | 9 |
#         Y=0| 0 | 30 |
# True Label  R=1 R=0
# Predict R=1| 5 | 2 |
#         R=0| 0 | 35 |
# True Label  B=1 B=0
# Predict B=1| 9 | 15 |
#         B=0| 0 | 18 |

# %%
for cm in kde_agent.colour_models.values():
    test_colour_model(cm)
    cm.draw()
    print(len(cm.data))
# Out:
# True Label  G=1 G=0
# Predict G=1| 10 | 3 |
#         G=0| 0 | 29 |
# 53
# True Label  Y=1 Y=0
# Predict Y=1| 3 | 4 |
#         Y=0| 0 | 35 |
# 43
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# 36
# True Label  B=1 B=0
# Predict B=1| 9 | 4 |
#         B=0| 0 | 29 |
# 38

# %%
for cm in kde_agent_neg.colour_models.values():
    test_colour_model(cm)
    cm.draw(draw_both=True)
    print(len(cm.data))
# Out:
# True Label  G=1 G=0
# Predict G=1| 10 | 1 |
#         G=0| 0 | 31 |
# 45
# True Label  Y=1 Y=0
# Predict Y=1| 3 | 3 |
#         Y=0| 0 | 36 |
# 40
# True Label  R=1 R=0
# Predict R=1| 5 | 1 |
#         R=0| 0 | 36 |
# 46
# True Label  B=1 B=0
# Predict B=1| 9 | 2 |
#         B=0| 0 | 31 |
# 48

# %%
r = kde_agent_neg.colour_models['red']

# %%
r.bw = lambda x: 0.05
r.update([0,0,0], 0.00000000001)

# %%
for cm in kde_agent_neg.colour_models.values():
    test_colour_model(cm)
    cm.draw(draw_both=True)
    print(len(cm.data))
# Out:
# True Label  G=1 G=0
# Predict G=1| 10 | 2 |
#         G=0| 0 | 30 |
# 45
# True Label  Y=1 Y=0
# Predict Y=1| 3 | 5 |
#         Y=0| 0 | 34 |
# 40
# True Label  R=1 R=0
# Predict R=1| 5 | 0 |
#         R=0| 0 | 37 |
# 50
# True Label  B=1 B=0
# Predict B=1| 9 | 3 |
#         B=0| 0 | 30 |
# 48

# %%
exp = load_experiments([76, 77, 68, 69], 'bijection')
exp.plot(labels=['gaussian', 'gaussian w/ negative', 'kde', 'kde w/ negative', 'naive'])

# %%
exp = load_experiments([78, 79, 66, 67], 'maroon')
exp.plot(labels=['gaussian', 'gaussian w/ negative', 'kde', 'kde w/ negative', 'naive'])
