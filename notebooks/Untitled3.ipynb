# %%
import sqlalchemy

# %%
db_location = "/home/mappelgren/Desktop/correcting-agent/db/experiments.db"
#db_location = "~/Desktop/correcting-agent/db/experiments.db"

# %%
engine = sqlalchemy.create_engine('sqlite:///' + db_location)

# %%
engine
# Out:
# Engine(sqlite:////home/mappelgren/Desktop/correcting-agent/db/experiments.db)

# %%
import pandas as pd

# %%
pd.read_sql('experiments', index_col='index', con=engine)
# Out:
#                               config_name  \
# index
# 0                                    None
# 1                           simple_neural
# 2                      neural_onerule5000
# 3                      neural_onerule5000
# 4                      neural_onerule5000
# 5                      neural_onerule5000
# 6                                tworules
# 7                      tworules_no_update
# 8                                tworules
# 9                      tworules_no_update
# 10                               tworules
# 11                                onerule
# 12                onerule_update_negative
# 13                               tworules
# 14               tworules_update_negative
# 15                tworules_perfect_colour
# 16            tworules_perfect_colour_vis
# 17                tworules_perfect_colour
# 18                               tworules
# 19               tworules_update_negative
# 20                               tworules
# ...

# %%
ls ~/Desktop/correcting-agent/data/onerule
# Out:
# problem10.pddl  problem1.pddl   problem29.pddl  problem38.pddl  problem47.pddl
# problem11.pddl  problem20.pddl  problem2.pddl   problem39.pddl  problem48.pddl
# problem12.pddl  problem21.pddl  problem30.pddl  problem3.pddl   problem49.pddl
# problem13.pddl  problem22.pddl  problem31.pddl  problem40.pddl  problem4.pddl
# problem14.pddl  problem23.pddl  problem32.pddl  problem41.pddl  problem50.pddl
# problem15.pddl  problem24.pddl  problem33.pddl  problem42.pddl  problem5.pddl
# problem16.pddl  problem25.pddl  problem34.pddl  problem43.pddl  problem6.pddl
# problem17.pddl  problem26.pddl  problem35.pddl  problem44.pddl  problem7.pddl
# problem18.pddl  problem27.pddl  problem36.pddl  problem45.pddl  problem8.pddl
# problem19.pddl  problem28.pddl  problem37.pddl  problem46.pddl  problem9.pddl
