# %%
from correctingagent.world.world_generation import *

# %%
generate_dataset_set_w_colour_count(50, 50, 1, 0, "colour_count_1_1", cc_exact_num=1)
generate_dataset_set_w_colour_count(50, 50, 1, 0, "colour_count_1_2", cc_exact_num=2)
generate_dataset_set_w_colour_count(50, 50, 1, 0, "colour_count_1_3", cc_exact_num=3)
generate_dataset_set_w_colour_count(50, 50, 2, 0, "colour_count_2_1", cc_exact_num=1)
generate_dataset_set_w_colour_count(50, 50, 2, 0, "colour_count_2_2", cc_exact_num=2)
generate_dataset_set_w_colour_count(50, 50, 2, 0, "colour_count_2_3", cc_exact_num=3)
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain-updated.pddl
# ...
