# %%
from prob_model import ColourModel
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')
sns.set_context("paper")
# %matplotlib inline

# %%
m = ColourModel('red')

# %%
#m.update(np.array([0.0, 0.0, 1.0]), 0.7)
m.draw(save_location_basename='boop')

# %%
m.update(np.array([0.0, 0.0, 1.0]), 1)
m.draw()

# %%
m = ColourModel('red')
for i in range(100):
    if i % 10 == 0:
        print(i, m.mu0, m.sigma0)
    m.update(np.array([0.0, 0.0, 1.0]), 0.2)
# Out:
# 0 [0.5 0.5 0.5] [1 1 1]
# 10 [0.16666667 0.16666667 0.83333333] [0.38888889 0.38888889 0.38888889]
# 20 [0.1 0.1 0.9] [0.24 0.24 0.24]
# 30 [0.07142857 0.07142857 0.92857143] [0.17346939 0.17346939 0.17346939]
# 40 [0.05555556 0.05555556 0.94444444] [0.13580247 0.13580247 0.13580247]
# 50 [0.04545455 0.04545455 0.95454545] [0.11157025 0.11157025 0.11157025]
# 60 [0.03846154 0.03846154 0.96153846] [0.09467456 0.09467456 0.09467456]
# 70 [0.03333333 0.03333333 0.96666667] [0.08222222 0.08222222 0.08222222]
# 80 [0.02941176 0.02941176 0.97058824] [0.07266436 0.07266436 0.07266436]
# 90 [0.02631579 0.02631579 0.97368421] [0.06509695 0.06509695 0.06509695]

# %%
m = ColourModel('red')
for i in range(100):
    if i % 10 == 0:
        print(i, m.mu0, m.sigma0)
    m.update(np.array([0.0, 0.0, 1.0]), 1.0)
# Out:
# 0 [0.5 0.5 0.5] [1 1 1]
# 10 [0.04545455 0.04545455 0.95454545] [0.11157025 0.11157025 0.11157025]
# 20 [0.02380952 0.02380952 0.97619048] [0.05895692 0.05895692 0.05895692]
# 30 [0.01612903 0.01612903 0.98387097] [0.04006243 0.04006243 0.04006243]
# 40 [0.01219512 0.01219512 0.98780488] [0.03033908 0.03033908 0.03033908]
# 50 [0.00980392 0.00980392 0.99019608] [0.02441369 0.02441369 0.02441369]
# 60 [0.00819672 0.00819672 0.99180328] [0.02042462 0.02042462 0.02042462]
# 70 [0.00704225 0.00704225 0.99295775] [0.01755604 0.01755604 0.01755604]
# 80 [0.00617284 0.00617284 0.99382716] [0.01539399 0.01539399 0.01539399]
# 90 [0.00549451 0.00549451 0.99450549] [0.01370607 0.01370607 0.01370607]
