# %%
from correctingagent.world.world_generation import *
from correctingagent.experiments.experiment import run_experiment
from correctingagent.world import world
from correctingagent.util.util import get_config
from pathlib import Path

# %%
r = [generate_rule(p_primary_colour=1.0) for i in range(2)]
cc = generate_biased_colour_counts(r)

# %%
p = problem_def.BlocksWorldProblem.generate_problem(['red']*10, r)
p.asPDDL()
# Out:
# '(define (problem blocks-problem)\n\t(:domain blocksworld)\n\t(:objects b0 b1 b2 b3 b4 b5 b6 b7 b8 b9 t0)\n\t(:init \n\t\t(arm-empty )\n\t\t(on-table b0)\n\t\t(clear b0)\n\t\t(on-table b1)\n\t\t(clear b1)\n\t\t(on-table b2)\n\t\t(clear b2)\n\t\t(on-table b3)\n\t\t(clear b3)\n\t\t(on-table b4)\n\t\t(clear b4)\n\t\t(on-table b5)\n\t\t(clear b5)\n\t\t(on-table b6)\n\t\t(clear b6)\n\t\t(on-table b7)\n\t\t(clear b7)\n\t\t(on-table b8)\n\t\t(clear b8)\n\t\t(on-table b9)\n\t\t(clear b9)\n\t\t(in-tower t0)\n\t\t(clear t0)\n\t\t(red b0)\n\t\t(red b1)\n\t\t(red b2)\n\t\t(red b3)\n\t\t(red b4)\n\t\t(red b5)\n\t\t(red b6)\n\t\t(red b7)\n\t\t(red b8)\n\t\t(red b9)\n\t)\n\t(:goal (and (forall (?x) (in-tower ?x)) (forall (?y) (or (not (pink ?y)) (exists (?x) (and (green ?x) (on ?x ?y))))) (forall (?x) (or (not (yellow ?x)) (exists (?y) (and (green ?y) (on ?x ?y)))))))\n)'

# %%
p.goal.subformulas[1]

# %%
generate_random_colour_from_colour_count(cc)
# Out:
# [('red', array([0.0277155 , 0.93314509, 0.94870695])),
#  ('purple', array([0.74518196, 0.87428083, 0.83021464])),
#  ('purple', array([0.77092426, 0.84659687, 0.90948231])),
#  ('red', array([0.9875275 , 0.98811071, 0.8318368 ])),
#  ('purple', array([0.73488853, 0.98916283, 0.80144551])),
#  ('red', array([0.00123429, 0.96647347, 0.98608822])),
#  ('purple', array([0.72161753, 0.94770714, 0.99376687])),
#  ('red', array([0.01522193, 0.94502475, 0.97681611])),
#  ('pink', array([0.84499195, 0.94182315, 0.89394189])),
#  ('blue', array([0.58763623, 0.91657304, 0.95870288]))]

# %%
generate_dataset_set(50, 50, 2, 'big_bijection_random_colours', p_primary_colour=1, create_bijection=True)
# generate_dataset_set(50, 50, 3, 'big_threerules_random_colours', p_primary_colour=1)
# generate_dataset_set(50, 50, 4, 'big_fourrules_random_colours', p_primary_colour=1)
# Out:
# [Ruledef(first_obj=['blue'], second_obj=['red'], constrained_obj='first'), Ruledef(first_obj=['blue'], second_obj=['red'], constrained_obj='second')]
# ['green', 'red', 'blue', 'blue', 'blue', 'red', 'red', 'pink', 'blue', 'red']
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# ['blue', 'red', 'blue', 'blue', 'red', 'blue', 'blue', 'red', 'red', 'red']
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# ['blue', 'red', 'red', 'green', 'red', 'blue', 'green', 'red', 'blue', 'blue']
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# ['orange', 'blue', 'red', 'red', 'yellow', 'blue', 'orange', 'yellow', 'red', 'blue']
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# ...

# %%
generate_biased_dataset(50, r, '/home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours', use_random_colours=True)
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem ../data/tmp/generation.pddl
# ...

# %%
config = get_config()
data_location = Path(config['data_location'])
problem_location = data_location / "testing"
w = world.RandomColoursWorld('blocks-domain.pddl', problem_location /  "problem1.pddl", problem_location / "colours1.json")
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/testing/problem1.pddl

# %%
w.draw()

# %%
run_experiment(config_name='tworules_random_colours_old_teacher', colour_model_config='fixed_bw_0.02')
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put orange blocks on yellow blocks
# Is the top object orange?
# yes
# tworules_random_colours reward: -28
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# ...

# %%
run_experiment(config_name='tworules_random_colours_old_teacher_no_correction', colour_model_config='fixed_bw_0.02')
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put orange blocks on yellow blocks
# Is the top object orange?
# yes
# tworules_random_colours reward: -20
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem2.pddl
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# tworules_random_colours reward: -12
# ...

# %%
run_experiment(config_name='tworules_random_colours_old_teacher_no_correction', colour_model_config='fixed_bw_0.01')
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put orange blocks on yellow blocks
# Is the top object orange?
# yes
# tworules_random_colours reward: -20
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem2.pddl
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# tworules_random_colours reward: -12
# ...

# %%
#debug_agent = {'show_cm_update': True, 'evaluate_cms':True}
debug_agent = None
run_experiment(config_name='tworules_random_colours_old_teacher_no_correction', colour_model_config='fixed_bw_0.05', 
               debug_agent=debug_agent)
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# T: no, put red blocks on purple blocks
# T: no, put orange blocks on yellow blocks
# Is the top object orange?
# yes
# T: No, now you cannot put b5 in the tower because you must put orange blocks on yellow blocks
# tworules_random_colours reward: -20
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem2.pddl
# tworules_random_colours reward: -10
# ...

# %%
debug_agent = {'show_cm_update': True, 'evaluate_cms':True}
run_experiment(config_name='tworules_random_colours_old_teacher_no_correction', colour_model_config='fixed_bw_0.02', 
               debug_agent=debug_agent)
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# Did not update red model with: [0.89886305 0.92854864 0.2077683 ] at probability 0.0
# Updated purple model with: [0.62171885 0.01123436 0.9709057 ] at probability 1.0
# Evaluating red model
# True Label  r=1 r=0
# Predict r=1| 0 | 0 |
#         r=0| 10 | 60 |
# Evaluating purple model
# True Label  p=1 p=0
# Predict p=1| 1 | 0 |
#         p=0| 9 | 60 |
# Did not update red model with: [0.89886305 0.92854864 0.2077683 ] at probability 0.0
# ...

# %%
run_experiment(config_name='tworules_random_colours_old_teacher_no_correction', colour_model_config='fixed_bw_0.01_hsv_1channel')
# Out:
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem1.pddl
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# T: no, put red blocks on purple blocks
# T: no, put red blocks on purple blocks
# T: no, put orange blocks on yellow blocks
# Is the top object orange?
# yes
# tworules_random_colours reward: -20
# Parsing domain /home/mappelgren/Desktop/correcting-agent/data/domain/blocks-domain.pddl
# Parsing problem /home/mappelgren/Desktop/correcting-agent/data/tworules_random_colours/problem2.pddl
# T: no, put red blocks on purple blocks
# Is the top object red?
# no
# tworules_random_colours reward: -12
# ...
