# %%
import os
from nltk.parse.stanford import StanfordDependencyParser
from matplotlib import pylab
import pydot
os.environ['STANFORD_PARSER'] = '/afs/inf.ed.ac.uk/user/s12/s1202144/Desktop/phd/src/jars'
os.environ['STANDFORD_MODELS'] = '/afs/inf.ed.ac.uk/user/s12/s1202144/Desktop/phd/src/jars'
os.environ['CLASSPATH'] = '/afs/inf.ed.ac.uk/user/s12/s1202144/Desktop/phd/src/jars'

# %%
def parse_sentence(sentence):
    parser = StanfordDependencyParser()
    parsed = parser.raw_parse(sentence)
    return parsed.__next__()

# %%
parse_sentence("put a green block on a blue block")
# Out:
# <DependencyGraph with 9 nodes>

# %%
import pddl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-460b4584a0e2> in <module>()
# ----> 1 import pddl
#
# ModuleNotFoundError: No module named 'pddl'
