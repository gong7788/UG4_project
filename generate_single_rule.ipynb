# %%
import problem_def
from colour_dict import colour_dict, simple_colour_dict
import world
import os
import random

# %%
from evaluation import *
filename = 'results/colours/bijection_blue_0.7.pickle'
extract_file(filename)

# %%
def sample_colour(colour_dict):
    category = random.choice(list(colour_dict.keys()))
    return random.choice(colour_dict[category])

def sample_colours(n, colour_dict=colour_dict):
    return [sample_colour(colour_dict) for i in range(n)]
 
print(sample_colours(10))
print(sample_colours(10, colour_dict=simple_colour_dict))
# Out:
# ['orange', 'purple', 'firebrick', 'fuchsia', 'darkorchid', 'midnightblue', 'lightpink', 'darkviolet', 'yellow', 'yellow']
# ['pink', 'red', 'yellow', 'yellow', 'green', 'yellow', 'green', 'red', 'red', 'red']

# %%
def generate_dataset(N, rules, directory, colour_dict=colour_dict):
    dataset = []
    while len(dataset) < N:
        colours = sample_colours(10, colour_dict=colour_dict)
        with open('tmp/generation.pddl', 'w') as f:
            f.write(problem_def.create_problem(colours, rules).asPDDL())
        w = world.PDDLWorld('blocks-domain.pddl', 'tmp/generation.pddl')
        if not w.test_failure():
            file_name = '{}/problem{}.pddl'.format(directory,len(dataset)+1)
            os.rename('tmp/generation.pddl', file_name)
            dataset.append(file_name)

# %%
rule1 = problem_def.Ruledef(['red'], ['blue'], 'first')
rule2 = problem_def.Ruledef(['green'], ['yellow'], 'second')
rule3 = problem_def.Ruledef(['red'], ['blue'], 'second')
rule4 = problem_def.Ruledef(['green'], ['maroon'], 'first')

# %%
generate_dataset(50, [rule1], 'onerule')
# Out:
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# no plan
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# running ff with blocks-domain.pddl tmp/world_problem.pddl
# default

# %%
generate_dataset(50, [rule1], 'simplecolours', colour_dict=simple_colour_dict)
# Out:
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl

# %%
generate_dataset(50, [rule1, rule2], 'tworules')
# Out:
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl

# %%
import ff
ff.run('blocks-domain.pddl', 'tmp/generation.pddl')
# Out:
# ---------------------------------------------------------------------------
# NoPlanError                               Traceback (most recent call last)
# <ipython-input-8-d5be6e6f12bb> in <module>()
#       1 import ff
# ----> 2 ff.run('blocks-domain.pddl', 'tmp/generation.pddl')
#
# ~/Desktop/correcting-agent/ff.py in run(domain, problem)
#      83
#      84 def run(domain, problem):
# ---> 85     result = ff(domain, problem)
#      86     return get_actions(result)
#      87
#
# ~/Desktop/correcting-agent/ff.py in ff(domain, problem)
#      41     exitCode = process.returncode
#      42     if "problem proven unsolvable" in output or "goal can be simplified to FALSE" in output:
# ---> 43         raise NoPlanError('No plan could be found')
#      44
#      45     elif "goal can be simplified to TRUE" in output:
#
# NoPlanError: No plan could be found

# %%
generate_dataset(50, [rule1, rule4], 'maroon2')
# Out:
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl

# %%
generate_dataset(50, [rule1, rule3], 'bijection')
# Out:
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
# Parsing domain blocks-domain.pddl
# Parsing problem tmp/generation.pddl
