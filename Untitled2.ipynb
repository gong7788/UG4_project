# %%
from experiment import add_experiment
from experiment_tracking import read_experiments, get_results_file, get_baseline, load_experiments
from evaluation import test_colour_model, colour_probs, colour_dict, name_to_rgb
from util import add_config_option, create_experiment

# %matplotlib inline

# %%
read_experiments()
# Out:
#                               config_name  \
# index
# 0                                    None
# 1                           simple_neural
# 2                      neural_onerule5000
# 3                      neural_onerule5000
# 4                      neural_onerule5000
# 5                      neural_onerule5000
# 6                                tworules
# 7                      tworules_no_update
# 8                                tworules
# 9                      tworules_no_update
# 10                               tworules
# 11                                onerule
# 12                onerule_update_negative
# 13                               tworules
# 14               tworules_update_negative
# 15                tworules_perfect_colour
# 16            tworules_perfect_colour_vis
# 17                tworules_perfect_colour
# 18                               tworules
# 19               tworules_update_negative
# 20                               tworules
# 21                               tworules
# 22               tworules_update_negative
# 23                   tworules_update_once
# 24                   tworules_update_once
# 25     tworules_update_once_with_negative
# 26                               tworules
# 27                               tworules
# 28                               tworules
# 29                               tworules
# ...                                   ...
# 133      maroon_update_once_with_negative
# 134    tworules_update_once_with_negative
# 135                          tworules_kde
# 136                          tworules_kde
# 137                          tworules_kde
# 138                    onerule_kde_nocorr
# 139                    onerule_kde_nocorr
# 140                   tworules_kde_nocorr
# 141                     simple_nolanguage
# 142                     simple_nolanguage
# 143                     simple_nolanguage
# 144                     simple_nolanguage
# 145                     simple_nolanguage
# 146                     simple_nolanguage
# 147                     simple_nolanguage
# 148                     simple_nolanguage
# 149                     simple_nolanguage
# 150                     simple_nolanguage
# 151                    onerule_nolanguage
# 152                   tworules_nolanguage
# 153                     simple_nolanguage
# 154                     simple_nolanguage
# 155                     simple_nolanguage
# 156                     simple_nolanguage
# 157                     simple_nolanguage
# 158                     simple_nolanguage
# 159                     simple_nolanguage
# 160                     simple_nolanguage
# 161                    onerule_nolanguage
# 162                   tworules_nolanguage
#
#                                          experiment_file  \
# index
# 0                                                   None
# 1      results/simplecolours/agents.NeuralCorrectingA...
# 2      results/onerule5000/agents.NeuralCorrectingAge...
# 3      results/onerule5000/agents.NeuralCorrectingAge...
# 4      results/onerule5000/agents.NeuralCorrectingAge...
# 5      results/onerule5000/agents.NeuralCorrectingAge...
# 6      results/tworules/agents.CorrectingAgent/0.7/ex...
# 7      results/tworules/agents.CorrectingAgent/0.7/ex...
# 8      results/tworules/agents.CorrectingAgent/0.7/ex...
# 9      results/tworules/agents.CorrectingAgent/0.7/ex...
# 10     results/tworules/agents.CorrectingAgent/0.7/ex...
# 11     results/onerule/agents.CorrectingAgent/0.7/exp...
# 12     results/onerule/agents.CorrectingAgent/0.7/exp...
# 13     results/tworules/agents.CorrectingAgent/0.7/ex...
# 14                                                  None
# 15     results/tworules/agents.PerfectColoursAgent/0....
# 16     results/tworules/agents.PerfectColoursAgent/0....
# 17                                                  None
# 18     results/tworules/agents.CorrectingAgent/0.7/ex...
# 19                                                  None
# 20                                                  None
# 21     results/tworules/agents.CorrectingAgent/0.7/ex...
# 22     results/tworules/agents.CorrectingAgent/0.7/ex...
# 23                                                  None
# 24     results/tworules/agents.CorrectingAgent/0.7/ex...
# 25     results/tworules/agents.CorrectingAgent/0.7/ex...
# 26                                                  None
# 27                                                  None
# 28                                                  None
# 29                                                  None
# ...                                                  ...
# 133    results/maroon/agents.CorrectingAgent/0.7/expe...
# 134    results/tworules/agents.CorrectingAgent/0.7/ex...
# 135    results/tworules/agents.CorrectingAgent/0.7/ex...
# 136    results/tworules/agents.CorrectingAgent/0.7/ex...
# 137                                                 None
# 138    results/onerule/agents.CorrectingAgent/0.7/exp...
# 139    results/onerule/agents.CorrectingAgent/0.7/exp...
# 140    results/tworules/agents.CorrectingAgent/0.7/ex...
# 141                                                 None
# 142                                                 None
# 143                                                 None
# 144                                                 None
# 145                                                 None
# 146                                                 None
# 147                                                 None
# 148                                                 None
# 149                                                 None
# 150    results/simplecolours/agents.NoLanguageAgent/0...
# 151    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 152    results/tworules/agents.NoLanguageAgent/0.7/ex...
# 153    results/simplecolours/agents.NoLanguageAgent/0...
# 154                                                 None
# 155                                                 None
# 156    results/simplecolours/agents.NoLanguageAgent/0...
# 157                                                 None
# 158    results/simplecolours/agents.NoLanguageAgent/0...
# 159    results/simplecolours/agents.NoLanguageAgent/0...
# 160    results/simplecolours/agents.NoLanguageAgent/0...
# 161    results/onerule/agents.NoLanguageAgent/0.7/exp...
# 162    results/tworules/agents.NoLanguageAgent/0.7/ex...
#
#                 neural_config   status
# index
# 0                        None     None
# 1                     DEFAULT     done
# 2                 adam_lr:0.1     done
# 3                   adam_lr:1     done
# 4        nesterov_lr:0.1mom:0     done
# 5      nesterov_lr:0.1mom:0.4     done
# 6                        None     done
# 7                        None     done
# 8                        None     done
# 9                        None     done
# 10                       None     done
# 11                       None     done
# 12                       None     done
# 13                       None     done
# 14                       None  running
# 15                       None     done
# 16                       None     done
# 17                       None  running
# 18                       None     done
# 19                       None  running
# 20                       None  running
# 21                       None     done
# 22                       None     done
# 23                       None  running
# 24                       None     done
# 25                       None     done
# 26                       None  running
# 27                       None  running
# 28                       None  running
# 29                       None  running
# ...                       ...      ...
# 133                      None     done
# 134                      None     done
# 135                  fixed_bw     done
# 136                  fixed_bw     done
# 137                  fixed_bw  running
# 138                  fixed_bw     done
# 139              fixed_bw_0.2     done
# 140                  fixed_bw     done
# 141                  fixed_bw  running
# 142                  fixed_bw  running
# 143                  fixed_bw  running
# 144                  fixed_bw  running
# 145                  fixed_bw  running
# 146                  fixed_bw  running
# 147                  fixed_bw  running
# 148                  fixed_bw  running
# 149                  fixed_bw  running
# 150                  fixed_bw     done
# 151                  fixed_bw     done
# 152                  fixed_bw     done
# 153                  fixed_bw     done
# 154                  fixed_bw  running
# 155                  fixed_bw  running
# 156                  fixed_bw     done
# 157                  fixed_bw  running
# 158                  fixed_bw     done
# 159                  fixed_bw     done
# 160                  fixed_bw     done
# 161                  fixed_bw     done
# 162                  fixed_bw     done
#
# [163 rows x 4 columns]

# %%
exp = load_experiments([53, 60, 160], 'simple')
exp.plot(labels=['gaussian', 'kde', 'no-language', 'naive'])

# %%
exp = load_experiments([107, 120, 130, 131,  138, 139, 161], 'onerule')
exp.plot(labels=['kde w/ search', 'gaussian w/ search & negative', 
                 'kde w/ search fixed', 'gaussian search fixed', 'kde nocorr', 
                 'kde 0.2', 'nolanguage', 'naive'])

# %%
exp = load_experiments([131, 130, 161], 'onerule')
exp.plot(labels=['gaussian', 'kde', 'nolanguage', 'naive'])

# %%
exp = load_experiments([ 127, 134, 162], 'tworules')
exp.plot(labels=['kde search fixed', 
                 'gaussian search fixed', 
                 'nolanguage', 'Naive'])
